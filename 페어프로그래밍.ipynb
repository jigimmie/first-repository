# %% [markdown]
# <a href="https://colab.research.google.com/github/jigimmie/first-repository/blob/master/%ED%8E%98%EC%96%B4%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) 정답 숫자 초기화 - 서로 다른 5개 숫자
# 2) 사용자에게 숫자 5개 입력받기
# 3) 정답 숫자와 입력 숫자 비교
# - 숫자만 일치 : ball
# - 숫자와 위치 모두 일치: strike
# 4) 결과 출력

# %%
from random import *
# 정답 숫자 초기화
ans = []
while len(ans) < 5:
  num = randint(1,9)
  if num not in ans:
    ans.append(num)

while True:

#사용자에게 숫자 5개 입력받기
  num = []
  for i in range(5):
    val = int(input("정수 값을 입력하세요."))
    num.append(val)

# 정답 숫자와 입력 숫자 비교
  strike = 0
  ball = 0
  for i in range(5):
    if ans[i] == num[i]:
     strike +=1
    elif num[i] in ans:
     ball +=1

#결과 출력
  print(f'{strike} strike{ball} ball')

  if strike == 5:
    print("정답입니다!")
    break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3173425920.py in <cell line: 0>()
#      12   num = []
#      13   for i in range(5):
# ---> 14     val = int(input("정수 값을 입력하세요."))
#      15     num.append(val)
#      16
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
from random import *
# 정답 숫자 초기화
ans = []
while len(ans) < 5:
  num = randint(1,9)
  if num not in ans:
    ans.append(num)

while True:

#사용자에게 숫자 5개 입력받기
  num = []
  num = list(map(int,input("정수 값 5개를 띄어서 입력하세요.").split()))


# 정답 숫자와 입력 숫자 비교
  strike = 0
  ball = 0
  for i in range(5):
    if ans[i] == num[i]:
     strike +=1
    elif num[i] in ans:
     ball +=1

#결과 출력
  print(f'{strike} strike {ball} ball')

  if strike == 5:
    print("축하합니다~ 정답입니다!")
    break
# Out:
# [8, 3, 9, 4, 1]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2010064840.py in <cell line: 0>()
#      12 #사용자에게 숫자 5개 입력받기
#      13   num = []
# ---> 14   num = list(map(int,input("정수 값 5개를 띄어서 입력하세요.").split()))
#      15
#      16
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
